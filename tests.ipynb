# %%
import torch.nn.functional as F
import torch

# %%
y = torch.tensor([1.0])
x = torch.tensor([1.1])
w = torch.tensor([2.2])
b = torch.tensor([0.0])

# %%
z = w*x + b
a = torch.sigmoid(z)
loss = F.binary_cross_entropy(a,y)
loss
# Out:
# tensor(0.0852)
